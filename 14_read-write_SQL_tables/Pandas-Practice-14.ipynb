# %% [markdown]
# https://blogs.oracle.com/connect/post/run-sql-data-queries-pandas

# %%
import pandas as pd
import cx_Oracle
import sqlalchemy

# %%
#This works as well
#engine = sqlalchemy.create_engine("oracle+cx_oracle://COVID:COVID@localhost/?service_name=orcl", arraysize=1000)

# %%
#this works too
engine = sqlalchemy.create_engine('oracle://COVID:COVID@127.0.0.1:1521/orcl')

# %%
#engine = sqlalchemy.create_engine('oracle+cx_oracle://COVID:COVID@127.0.0.1:1521/?service_name=orcl')

# %%
df = pd.read_sql_table("COVID_DEATHS",engine,columns=['continent','location','dates','population','total_cases'])

# %%
df.head()
# Out:
#   continent     location      dates  population  total_cases
# 0      Asia  Afghanistan 2020-05-23  39835428.0       9952.0
# 1      Asia  Afghanistan 2020-05-24  39835428.0      10668.0
# 2      Asia  Afghanistan 2020-05-25  39835428.0      11180.0
# 3      Asia  Afghanistan 2020-05-26  39835428.0      11917.0
# 4      Asia  Afghanistan 2020-05-27  39835428.0      12465.0

# %%
covid_sql = '''SELECT * FROM COVID_DEATHS'''
df = pd.read_sql_query(covid_sql,engine)
df
# Out:
#        iso_code continent     location      dates  population  total_cases  \
# 0           AFG      Asia  Afghanistan 2020-05-23  39835428.0       9952.0
# 1           AFG      Asia  Afghanistan 2020-05-24  39835428.0      10668.0
# 2           AFG      Asia  Afghanistan 2020-05-25  39835428.0      11180.0
# 3           AFG      Asia  Afghanistan 2020-05-26  39835428.0      11917.0
# 4           AFG      Asia  Afghanistan 2020-05-27  39835428.0      12465.0
# ...         ...       ...          ...        ...         ...          ...
# 177721      YEM      Asia        Yemen 2020-07-31  30490639.0       1728.0
# 177722      YEM      Asia        Yemen 2020-08-01  30490639.0       1730.0
# 177723      YEM      Asia        Yemen 2020-08-02  30490639.0       1734.0
# 177724      YEM      Asia        Yemen 2020-08-03  30490639.0       1734.0
# 177725      YEM      Asia        Yemen 2020-08-04  30490639.0       1760.0
#
# ...
